# %%
from pathlib import Path
text = Path('components/EigoMaster.tsx').read_text(encoding='utf-8')
lines = text.splitlines()
for i, line in enumerate(lines[-80:], start=len(lines)-79):
    print(f'{i:5}: {line}')
